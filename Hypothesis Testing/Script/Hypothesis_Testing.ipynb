# %% [markdown]
# Q1) A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions.
#
#
#      Minitab File : Cutlets.mtw

# %% [markdown]
# Ans) Null_Hypothesis=There is no significant difference between two cutlet samples.
#
# Alternate_Hypothesis=There is a significant difference between two cutlet samples.
#
# Alpha1=5%=0.05

# %%
import pandas as pd
import scipy.stats as stats

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bb604021-aca1-4146-b098-1d5ac4dca9a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb604021-aca1-4146-b098-1d5ac4dca9a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Cutlets=pd.read_csv('Cutlets.csv')
Cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
a=Cutlets['Unit A']
a
# Out:
# 0     6.8090
# 1     6.4376
# 2     6.9157
# 3     7.3012
# 4     7.4488
# 5     7.3871
# 6     6.8755
# 7     7.0621
# 8     6.6840
# 9     6.8236
# 10    7.3930
# 11    7.5169
# 12    6.9246
# 13    6.9256
# 14    6.5797
# 15    6.8394
# 16    6.5970
# 17    7.2705
# 18    7.2828
# 19    7.3495
# 20    6.9438
# 21    7.1560
# 22    6.5341
# 23    7.2854
# 24    6.9952
# 25    6.8568
# 26    7.2163
# 27    6.6801
# 28    6.9431
# 29    7.0852
# 30    6.7794
# 31    7.2783
# 32    7.1561
# 33    7.3943
# 34    6.9405
# Name: Unit A, dtype: float64

# %%
b=Cutlets['Unit B']
b
# Out:
# 0     6.7703
# 1     7.5093
# 2     6.7300
# 3     6.7878
# 4     7.1522
# 5     6.8110
# 6     7.2212
# 7     6.6606
# 8     7.2402
# 9     7.0503
# 10    6.8810
# 11    7.4059
# 12    6.7652
# 13    6.0380
# 14    7.1581
# 15    7.0240
# 16    6.6672
# 17    7.4314
# 18    7.3070
# 19    6.7478
# 20    6.8889
# 21    7.4220
# 22    6.5217
# 23    7.1688
# 24    6.7594
# 25    6.9399
# 26    7.0133
# 27    6.9182
# 28    6.3346
# 29    7.5459
# 30    7.0992
# 31    7.1180
# 32    6.6965
# 33    6.5780
# 34    7.3875
# Name: Unit B, dtype: float64

# %%
Alpha1=0.05
T_test_Value=stats.ttest_ind(a,b)
T_test_Value
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %%
pvalue1=0.4722394724599501
print(pvalue1)
if pvalue<Alpha1:
  print("Accept Alternate Hypothesis:There is significant difference between cutlet samples from two outlets")
else:
  print("Failed to Reject Null  Hypothesis:Hence we accept Null Hypothesis, There is no significant difference between cutlet samples from two outlets")
# Out:
# 0.4722394724599501
# Failed to Reject Null  Hypothesis:Hence we accept Null Hypothesis, There is no significant difference between cutlet samples from two outlets

# %% [markdown]
# Q2) A hospital wants to determine whether there is any difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list. They collected a random sample and recorded TAT for reports of 4 laboratories. TAT is defined as sample collected to report dispatch.
#
# Analyze the data and determine whether there is any difference in average TAT among the different laboratories at 5% significance level.
#
#
#     Minitab File: LabTAT.mtw

# %% [markdown]
# Ans) Here we are taking 4 samples and comparing. So, we use ANOVA test for this.
#
# Null_Hypothesis = All samples are related. (MEAN OF ALL SAMPLES ARE EQUAL)
#
# Alternate_Hypothesis=All samples are not related. (MEAN OF ALL SAMPLES ARE NOT EQUAL)
#
# Alpha2=0.05

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-15e33086-8397-4f35-a5da-688e0458a5a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15e33086-8397-4f35-a5da-688e0458a5a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
LabTAT=pd.read_csv('LabTAT.csv')
LabTAT
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
Laboratory_1=LabTAT['Laboratory 1'].mean()
Laboratory_2=LabTAT['Laboratory 2'].mean()
Laboratory_3=LabTAT['Laboratory 3'].mean()
Laboratory_4=LabTAT['Laboratory 4'].mean()

print('Laboratory 1 Mean = ',Laboratory_1)
print('Laboratory 2 Mean = ',Laboratory_2)
print('Laboratory 3 Mean = ',Laboratory_3)
print('Laboratory 4 Mean = ',Laboratory_4)
# Out:
# Laboratory 1 Mean =  178.36158333333336
# Laboratory 2 Mean =  178.9029166666667
# Laboratory 3 Mean =  199.91324999999998
# Laboratory 4 Mean =  163.68275

# %%
#ANOVA TESTING
Alpha2=0.05
Anova=stats.f_oneway(LabTAT.iloc[:,0],LabTAT.iloc[:,1],LabTAT.iloc[:,2],LabTAT.iloc[:,3])
Anova
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
pvalue2=2.1156708949992414e-57
print(pvalue2)
if pvalue2<=Alpha2:
  print("Accept Alternate Hypothesis, So that All the datas are not related to each other")
else:
  print("Failed to Reject Null Hypothesis, So that All the datas are related to each other")
# Out:
# 2.1156708949992414e-57
# Accept Alternate Hypothesis, So that All the datas are not related to each other

# %% [markdown]
# Q3)
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-013aee16-cbd4-4bc0-9288-ca775e82ceea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-013aee16-cbd4-4bc0-9288-ca775e82ceea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
BuyerRatio=pd.read_csv('BuyerRatio.csv')
BuyerRatio
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
Alpha3=0.05

# %%
East=BuyerRatio['East'].mean()
West=BuyerRatio['West'].mean()
North=BuyerRatio['North'].mean()
South=BuyerRatio['South'].mean()

print('East Mean = ',East)
print('West Mean = ',West)
print('North Mean = ',North)
print('South Mean = ',South)
# Out:
# East Mean =  242.5
# West Mean =  832.5
# North Mean =  743.5
# South Mean =  410.0

# %%
BuyerRatio.set_index('Observed Values',inplace=True)
BuyerRatio
# Out:
#                  East  West  North  South
# Observed Values
# Males              50   142    131     70
# Females           435  1523   1356    750

# %%
Chi_test=stats.chi2_contingency(BuyerRatio)
Chi_test
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
pvalue3=0.6603094907091882
print(pvalue3)
if pvalue3<=Alpha3:
  print("Accept Alternate Hypothesis: So that Not all proportions are equal, Which means Male and Female buyer ratios are similar across all regions")
else:
  print("Failed to Reject Null Hypothesis: So that all proportions are equal, Which means Male and Female buyer ratios are not similar across all regions")
# Out:
# 0.6603094907091882
# Failed to Reject Null Hypothesis: So that all proportions are equal, Which means Male and Female buyer ratios are not similar across all regions

# %% [markdown]
# Q4) TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain %  of the customer order forms. Any error in order form renders it defective and has to be reworked before processing.  The manager wants to check whether the defective %  varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences
#
# Minitab File: CustomerOrderForm.mtw

# %% [markdown]
# Ans) Null_Hypothesis = Percentage of Defective ones which does not varies by center.
#
# Alternate_Hypothesis = Percentage of Defective ones which varies by center.

# %%
import pandas as pd
from scipy import stats as stats
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-eef90e77-4452-4ed2-98e7-e57afc1795c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eef90e77-4452-4ed2-98e7-e57afc1795c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Costomer_OrderForm=pd.read_csv('Costomer+OrderForm.csv')
Costomer_OrderForm
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %% [markdown]
# Here, More than 2 datas and categorical so we need to get Chi square test for it. So, we need to convert string to Numbers or Percentages.

# %%
Costomer_OrderForm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
print(Costomer_OrderForm['Phillippines'].value_counts(),Costomer_OrderForm['Indonesia'].value_counts(),
      Costomer_OrderForm['Malta'].value_counts(),Costomer_OrderForm['India'].value_counts())
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64 Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64 Error Free    269
# Defective      31
# Name: Malta, dtype: int64 Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
Data_Filtered=([[271,267,269,280],[29,33,31,20]])
Data_Filtered
# Out:
# [[271, 267, 269, 280], [29, 33, 31, 20]]

# %%
chi_square_test=chi2_contingency(Data_Filtered)
chi_square_test
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
Alpha4=0.05

# %%
pvalue4=0.2771020991233135
pvalue4
if pvalue4<Alpha4:
  print("Accept Alternate Hypothesis: So, all the variables are dependent")
else:
  print("Failed to Reject Null Hypothesis: So, all the variables are independent")
# Out:
# Failed to Reject Null Hypothesis: So, all the variables are independent
